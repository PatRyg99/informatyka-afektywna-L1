# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, classification_report

# %%
experiment_path = "output/11-22-2022.23:17:01"
train_predictions = os.path.join(experiment_path, "train_predictions.csv")
val_predictions = os.path.join(experiment_path, "val_predictions.csv")

# %% [markdown]
# ## Emotions map
#
# 0. neutral
# 1. anger
# 2. contempt
# 3. disgust
# 4. fear
# 5. happy
# 6. sadness
# 7. surprise

# %% [markdown]
# ## Training data

# %%
train_df = pd.read_csv(train_predictions)

print(classification_report(train_df["true"], train_df["predicted"]))
disp = ConfusionMatrixDisplay.from_predictions(train_df["true"], train_df["predicted"])
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      0.92      0.83       190
#            2       0.62      0.96      0.75        55
#            3       0.90      0.75      0.82       189
#            4       0.95      0.74      0.83        94
#            5       0.98      0.97      0.98       247
#            6       0.88      0.71      0.79        97
#            7       0.98      0.98      0.98       276
#
#     accuracy                           0.89      1148
#    macro avg       0.87      0.86      0.85      1148
# weighted avg       0.90      0.89      0.89      1148

# %% [markdown]
# ## Validation data

# %%
val_df = pd.read_csv(val_predictions)

print(classification_report(val_df["true"], val_df["predicted"]))
disp = ConfusionMatrixDisplay.from_predictions(val_df["true"], val_df["predicted"])
# Out:
#               precision    recall  f1-score   support
#
#            1       0.69      0.64      0.66        77
#            2       0.67      0.82      0.74        17
#            3       0.84      0.75      0.79        68
#            4       0.89      0.64      0.74        50
#            5       0.89      0.92      0.91       116
#            6       0.64      0.90      0.75        51
#            7       0.96      0.94      0.95       105
#
#     accuracy                           0.82       484
#    macro avg       0.80      0.80      0.79       484
# weighted avg       0.83      0.82      0.82       484
